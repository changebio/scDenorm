# %% [markdown]
# # Load

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# %matplotlib inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scanpy as sc
from anndata import AnnData
from scipy.sparse import diags
from scipy.io import mmwrite
from scipy import sparse
from scipy.optimize import fsolve,minimize
from tqdm import tqdm
from pathlib import Path
from typing import Union, Optional
import pickle
import seaborn as sns

# %%
from scDenorm.denorm import *

# %%
from scAnnot.tools import *

# %%
import matplotlib as mpl
sc.set_figure_params(scanpy=True, fontsize=14,facecolor=None,frameon=False,transparent=True)
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.grid'] = False

# %%
def solve_bc(p,y1,y2):
    return sum((np.exp(y2*np.log(p[0]))-2*np.exp(y1*np.log(p[0]))+p[1])**2)

# %%
from scipy.optimize import curve_fit

def fit_nb(ms):
    
    def nb_func(x, phi):
        return x[0] + (phi * x[0] ** 2)
    
    popt, _ = curve_fit(nb_func, ms['mean'], ms['var'], p0=[1])
    phi = popt[0]
    
    ms['zeros_p'] = np.exp(-ms['mean'])
    ms['zeros_nb'] = (1 + phi * ms['mean']) ** (-1 / phi)
    ms['newVar'] = ms['mean'] + phi * ms['mean'] ** 2
    return ms

# %%
def plot_mv(cmean,cvar,ax,title,c='blue',fit=False,save=None):
    ax.loglog()
    ax.scatter(cmean, cvar,s=20,c=c)
    lims = [
        np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
        np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
    ]

    ax.plot(lims, lims, linestyle='--', linewidth=2, alpha=0.75, zorder=0,color='black', label='line')
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    ax.spines[['right', 'top']].set_visible(False)
    ax.set_xlabel('Mean')
    ax.set_ylabel('Variance')
    ax.set_title(title)
    
    if fit:
        ms=pd.DataFrame({'mean':cmean[0],'var':cvar[0]})
        ms=fit_nb(ms)
        ms=ms.sort_values('mean')
        ax.plot(ms['mean'],ms['newVar'],'k-', alpha=1, zorder=ms.shape[0],color='red', label='line')
    if save:
        plt.savefig(save,dpi=300, bbox_inches='tight',transparent=True)

# %% [markdown]
# # Read UCB meta

# %% [markdown]
# ## Fig 5A,B

# %%
ucb_meta=pd.read_csv('data/ucb_meta.csv',index_col=0)

# %%
ucb_meta=ucb_meta[~ucb_meta.index.isin(['human-fovea-periphery','gbm','cbl-dev'])]

# %%
ucb_meta['base'][ucb_meta['base']=='1']='Without'
ucb_meta['base'][ucb_meta['base']=='e']='Log'
ucb_meta['base'][ucb_meta['base']=='2']='Log2'
ucb_meta['base'][ucb_meta['base'].isna()]='Unknown'
# Out:
# /tmp/ipykernel_17408/1457734253.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ucb_meta['base'][ucb_meta['base']=='e']='Log'
# /tmp/ipykernel_17408/1457734253.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ucb_meta['base'][ucb_meta['base']=='2']='Log2'
# /tmp/ipykernel_17408/1457734253.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ucb_meta['base'][ucb_meta['base'].isna()]='Unknown'

# %%
tmp=pd.DataFrame(ucb_meta['base'].value_counts())

# %%
tmp['name']=list(tmp.index)

# %%
tmp['name']=pd.Categorical(tmp['name'], categories=['Log', 'Log2', 'Without','Unknown'], ordered=True)

# %%
figsize(4,4)
sns.barplot(y='name',x='base', data=tmp)
sns.despine()
plt.ylabel('Transform')
plt.xlabel('Number of datasets')
plt.savefig('figures/UCB/ucb_meta1.pdf',dpi=300, bbox_inches='tight',transparent=True)

# %%
figsize(3,4)
sns.barplot(x='name',y='base', data=tmp)
sns.despine()
plt.xlabel('Transform')
plt.ylabel('Number of datasets')
plt.xticks(rotation=90)
plt.yticks([0,10,20])
plt.savefig('figures/UCB/ucb_meta1.pdf',dpi=300, bbox_inches='tight',transparent=True)

# %%
cmap = plt.get_cmap("tab10")

# %%
cmap

# %%
ck={
    'Log':cmap(0),
    'Log2':cmap(1),
    'Without':cmap(2),
    'Unknown':cmap(3)}

# %%
ucb_meta['base'] = pd.Categorical(ucb_meta['base'], categories=['Log', 'Log2', 'Without','Unknown'], ordered=True)

# %%
ucb_meta=ucb_meta.sort_values('base')

# %%
ucb_meta
# Out:
#                                                       name  \
# adult-testis                                  adult-testis
# covid19-periph-immuno                covid19-periph-immuno
# fetal-lung                                      fetal-lung
# fetal-liver                                    fetal-liver
# human-epidermis                            human-epidermis
# covid19-cytokine-storm              covid19-cytokine-storm
# colorectal-cancer                        colorectal-cancer
# brain-dronc-seq                            brain-dronc-seq
# aging-brain                                    aging-brain
# human-cornea                                  human-cornea
# human-gallbladder                        human-gallbladder
# lung-interstitial-macrophage  lung-interstitial-macrophage
# retinal-pigment-epi                    retinal-pigment-epi
# prostate-prostatic-urethra      prostate-prostatic-urethra
# hpsc-embryo-model                        hpsc-embryo-model
# mouse-osteoblasts                        mouse-osteoblasts
# mouse-dev-neocortex                    mouse-dev-neocortex
# mouse-cell-atlas                          mouse-cell-atlas
# sea-urchin-dev                              sea-urchin-dev
# lung-smoking-effect                    lung-smoking-effect
# ln-mono-dc                                      ln-mono-dc
# living-donor-kidney                    living-donor-kidney
# human-pancreas                              human-pancreas
# human-ileum                                    human-ileum
# human-hippo-axis                          human-hippo-axis
# mouse-esophagus                            mouse-esophagus
# human-cellular-landscape          human-cellular-landscape
# human-liver                                    human-liver
# ms                                                      ms
# autism                                              autism
# zeisel2015                                      zeisel2015
# klein-xenopus                                klein-xenopus
# gtex8                                                gtex8
# h1-esc-diff                                    h1-esc-diff
# head-neck                                        head-neck
# cortex-dev                                      cortex-dev
# mouse-hypothalamus-dev              mouse-hypothalamus-dev
# healthy-bal                                    healthy-bal
# mouse-skin-stretch                      mouse-skin-stretch
# organoidatlas                                organoidatlas
#
#                                                                      shortLabel  \
# adult-testis                                                       Adult Testis
# covid19-periph-immuno         Peripheral Immune in COVID-19 Infection (Wilk ...
# fetal-lung                                                           Fetal Lung
# fetal-liver                                            Fetal Liver and Yolk Sac
# human-epidermis                             Normal and Inflamed Human Epidermis
# covid19-cytokine-storm        Monocyte-associated Cytokine Storm in Severe C...
# colorectal-cancer                                             Colorectal Cancer
# brain-dronc-seq                   DroNc-seq of Human Brain (Habib et al. 2017.)
# aging-brain                                                         Aging Brain
# human-cornea                                                       Human Cornea
# human-gallbladder                 Gallbladder (Sampaziotis et al. Unpublished.)
# lung-interstitial-macrophage                Lung Interstitial Macrophages (IMs)
# retinal-pigment-epi                                  Retinal Pigment Epithelium
# prostate-prostatic-urethra                       Prostate and Prostatic Urethra
# hpsc-embryo-model                       Modeling Embryo Development using hPSCs
# mouse-osteoblasts                      Bone-Marrow Derived Osteoblasts in Mouse
# mouse-dev-neocortex                               Neocortex in Developing Mouse
# mouse-cell-atlas                                               Mouse Cell Atlas
# sea-urchin-dev                                           Sea Urchin Development
# lung-smoking-effect                   Smoking Effect on Human Airway Epithelium
# ln-mono-dc                    Migratory Dendritic Cells Direct Monocytes int...
# living-donor-kidney                                         Living Donor Kidney
# human-pancreas                                                   Human Pancreas
# human-ileum                                                         Human Ileum
# human-hippo-axis                                         Human Hippocampal Axis
# mouse-esophagus                                     Mouse Esophageal Epithelium
# human-cellular-landscape                               Human Cellular Landscape
# human-liver                                                         Human Liver
# ms                                                           Multiple Sclerosis
# autism                                                                   Autism
# zeisel2015                                         Mouse cortex and hippocampus
# klein-xenopus                                                 Klein-lab Xenopus
# gtex8                                                  GTEx RNA-seq Analysis V8
# h1-esc-diff                   Neurally-differentiated H1 Human Embryonic Ste...
# head-neck                                                  Head and Neck Cancer
# cortex-dev                                                   Cortex development
# mouse-hypothalamus-dev                           Mouse Hypothalamus Development
# healthy-bal                                         Airway Macrophage Diversity
# mouse-skin-stretch                                  Mouse Skin Stretch Response
# organoidatlas                                                Brain and organoid
#
#                                  base  genes          method
# adult-testis                      Log  27826         logNorm
# covid19-periph-immuno             Log  26361         logNorm
# fetal-lung                        Log  23832         logNorm
# fetal-liver                       Log  26349         logNorm
# human-epidermis                   Log  19791         logNorm
# covid19-cytokine-storm            Log  18670         logNorm
# colorectal-cancer                 Log  33694         logNorm
# brain-dronc-seq                   Log  25587         logNorm
# aging-brain                       Log  19746         logNorm
# human-cornea                      Log  33538         logNorm
# human-gallbladder                 Log     21         logNorm
# lung-interstitial-macrophage      Log  15171         logNorm
# retinal-pigment-epi               Log  21040         logNorm
# prostate-prostatic-urethra        Log  22875         logNorm
# hpsc-embryo-model                 Log  19798         logNorm
# mouse-osteoblasts                 Log  17275         logNorm
# mouse-dev-neocortex               Log  14498         logNorm
# mouse-cell-atlas                  Log   3005         logNorm
# sea-urchin-dev                    Log  21823         logNorm
# lung-smoking-effect               Log  20952         logNorm
# ln-mono-dc                        Log  17863         logNorm
# living-donor-kidney               Log  22484         logNorm
# human-pancreas                    Log  16077         logNorm
# human-ileum                       Log  22340         logNorm
# human-hippo-axis                  Log  17180         logNorm
# mouse-esophagus                   Log  14389         logNorm
# human-cellular-landscape          Log   1772         logNorm
# human-liver                      Log2  20007         logNorm
# ms                               Log2  33741         logNorm
# autism                           Log2  36501         logNorm
# zeisel2015                       Log2  19972         logNorm
# klein-xenopus                 Without  26550            Norm
# gtex8                         Unknown  56200             TPM
# h1-esc-diff                   Unknown  23045    log2(FPKM+1)
# head-neck                     Unknown  20348  log2(TPM/10+1)
# cortex-dev                    Unknown  56865             TPM
# mouse-hypothalamus-dev        Unknown   2000     SCTransform
# healthy-bal                   Unknown   3000     SCTransform
# mouse-skin-stretch            Unknown    299           scran
# organoidatlas                 Unknown   2000  scaled logNorm

# %%
figsize(10,3)
sns.barplot(x='name', y='genes', data=ucb_meta, palette=[ck[i] for i in ucb_meta['base']])
sns.despine()
plt.grid(visible=False)
plt.xlabel('Datasets')
plt.ylabel('Number of genes')
plt.xticks(rotation=90)
plt.savefig('figures/UCB/ucb_meta1.pdf',dpi=300, bbox_inches='tight',transparent=True)

# %%
figsize(4,4)
values = ucb_meta['method'][ucb_meta['base']=='Unknown'].value_counts()
plt.pie(values, labels=values.index)
# Out:
# ([<matplotlib.patches.Wedge>,
#   <matplotlib.patches.Wedge>,
#   <matplotlib.patches.Wedge>,
#   <matplotlib.patches.Wedge>,
#   <matplotlib.patches.Wedge>,
#   <matplotlib.patches.Wedge>],
#  [Text(0.7778174593052024, 0.7778174593052023, 'TPM'),
#   Text(-0.7778174593052023, 0.7778174593052024, 'SCTransform'),
#   Text(-1.0162674857624157, -0.4209517756015987, 'log2(FPKM+1)'),
#   Text(-0.4209517756015994, -1.0162674857624152, 'log2(TPM/10+1)'),
#   Text(0.420951775601599, -1.0162674857624154, 'scran'),
#   Text(1.0162674857624152, -0.42095177560159946, 'scaled logNorm')])

# %% [markdown]
# # Data

# %%
with open(f'data/results/ucb_all.pickle', 'rb') as handle:
    ads=pickle.load(handle)

# %%
len(ads.keys())
# Out:
# 43

# %%
h5_names=['adult-testis', 'aging-brain', 'brain-dronc-seq', 'colorectal-cancer', 'covid19-cytokine-storm', 'covid19-periph-immuno','fetal-liver', 'fetal-lung', 'hpsc-embryo-model', 'human-cellular-landscape', 'human-cornea', 'human-epidermis', 'human-gallbladder', 'human-hippo-axis', 'human-ileum', 'human-pancreas',  'living-donor-kidney', 'ln-mono-dc', 'lung-interstitial-macrophage', 'lung-smoking-effect', 'mouse-cell-atlas', 'mouse-dev-neocortex', 'mouse-esophagus', 'mouse-osteoblasts',  'prostate-prostatic-urethra', 'retinal-pigment-epi', 'sea-urchin-dev']

# %%
len(h5_names)
# Out:
# 27

# %%
total_sum=[]
for i in h5_names:
    print(i)
    smtx1=ads[i].X.copy()
    smtx1.data=np.exp(smtx1.data)-1
    total_sum.append(pd.DataFrame(smtx1.sum(axis=1)))
# Out:
# adult-testis
# aging-brain
# brain-dronc-seq
# colorectal-cancer
# covid19-cytokine-storm
# covid19-periph-immuno
# fetal-liver
# fetal-lung
# hpsc-embryo-model
# human-cellular-landscape
# human-cornea
# human-epidermis
# human-gallbladder
# human-hippo-axis
# human-ileum
# human-pancreas
# living-donor-kidney
# ln-mono-dc
# lung-interstitial-macrophage
# lung-smoking-effect
# mouse-cell-atlas
# mouse-dev-neocortex
# mouse-esophagus
# mouse-osteoblasts
# prostate-prostatic-urethra
# retinal-pigment-epi
# sea-urchin-dev

# %%
summary_ts=[]
for i,j in enumerate(h5_names):
    summary_ts.append([i+1,j,np.mean(total_sum[i])[0],np.std(total_sum[i])[0]])
# Out:
# /home/huang_yin/anaconda3/envs/sc/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
pd.DataFrame(summary_ts)
# Out:
#      0                             1             2            3
# 0    1                  adult-testis  10000.000000     0.001288
# 1    2                   aging-brain  10000.000000     0.000806
# 2    3               brain-dronc-seq  10000.000000     0.002515
# 3    4             colorectal-cancer  10000.000000     0.000634
# 4    5        covid19-cytokine-storm   9995.852539     2.675778
# 5    6         covid19-periph-immuno   1542.547974    93.809105
# 6    7                   fetal-liver  10000.000000     0.000986
# 7    8                    fetal-lung  10000.000000     0.001127
# 8    9             hpsc-embryo-model  10000.000000     0.000608
# 9   10      human-cellular-landscape   1115.062988   381.980469
# 10  11                  human-cornea  10000.000000     0.000838
# 11  12               human-epidermis  10000.000000     0.001013
# 12  13             human-gallbladder     76.526001    74.812439
# 13  14              human-hippo-axis  10000.000000     0.000938
# 14  15                   human-ileum  10000.000000     0.001881
# 15  16                human-pancreas  10000.000000     0.001487
# 16  17           living-donor-kidney   5996.942871   863.713562
# 17  18                    ln-mono-dc  11864.352539   588.452576
# 18  19  lung-interstitial-macrophage   7292.123047   516.145691
# 19  20           lung-smoking-effect  23344.820312  1353.486450
# 20  21              mouse-cell-atlas   1859.232300   485.281372
# 21  22           mouse-dev-neocortex  10000.000000     0.000771
# 22  23               mouse-esophagus  10000.000000     0.000902
# 23  24             mouse-osteoblasts  10367.000000     0.001090
# 24  25    prostate-prostatic-urethra  10000.000000     0.001224
# 25  26           retinal-pigment-epi  10000.000000     0.001208
# 26  27                sea-urchin-dev  10000.000000     0.000625

# %%
total_sum=pd.concat(total_sum)

# %%
total_sum.columns=['total']

# %%
total_sum['name']=[x for x in h5_names for i in range(1000)]

# %%
total_sum
# Out:
#             total            name
# 0    10000.001953    adult-testis
# 1     9999.999023    adult-testis
# 2    10000.000000    adult-testis
# 3     9999.998047    adult-testis
# 4     9999.998047    adult-testis
# ..            ...             ...
# 995  10000.000000  sea-urchin-dev
# 996  10000.000977  sea-urchin-dev
# 997   9999.999023  sea-urchin-dev
# 998  10000.000977  sea-urchin-dev
# 999  10000.000000  sea-urchin-dev
#
# [27000 rows x 2 columns]

# %% [markdown]
# ## Fig 5.C

# %%
figsize(3.5,7)
fig,ax=plt.subplots()
sns.boxplot(data=total_sum,y='name',x='total',ax=ax)
ax.set_xscale("log", base=10)
plt.grid(visible=False)
plt.xlabel('Total values')
plt.ylabel('Datasets')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
xticks = [1e2, 1e3, 1e4]
xtick_labels = [r'$10^{2}$', r'$10^{3}$', r'$10^{4}$']
plt.xticks(xticks, xtick_labels)
plt.savefig('figures/UCB/scaling_factors_all.pdf',dpi=300, bbox_inches='tight',transparent=True)

# %% [markdown]
# # rounding errors

# %%
ads_dn=[]
rounding_ers=[]
for i in h5_names:
    print(i)
    ad=ads[i]
    ad1=scdenorm(ad,verbose=1)
    ad1.X.sort_indices()
    
    ad2=scdenorm(ad,verbose=1,rint=False)
    ad2.X.sort_indices()

    tmp2=ad1.X.copy()
    tmp2.data=tmp2.data-ad2.X.data
    rounding_ers.append(tmp2.copy())
    ads_dn.append(ad1.X.copy())
# Out:
# INFO:root:The dimensions of this data are (1000, 27826).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# adult-testis
# 100%|██████████| 1000/1000 [00:00<00:00, 1679.11it/s]
# INFO:root:The dimensions of this data are (1000, 27826).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1702.32it/s]
# INFO:root:The dimensions of this data are (1000, 19746).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# aging-brain
# 100%|██████████| 1000/1000 [00:00<00:00, 1777.96it/s]
# INFO:root:The dimensions of this data are (1000, 19746).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1787.75it/s]
# INFO:root:The dimensions of this data are (1000, 25587).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# brain-dronc-seq
# 100%|██████████| 1000/1000 [00:00<00:00, 1810.64it/s]
# INFO:root:The dimensions of this data are (1000, 25587).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1832.55it/s]
# INFO:root:The dimensions of this data are (1000, 33694).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# colorectal-cancer
# 100%|██████████| 1000/1000 [00:00<00:00, 1655.50it/s]
# INFO:root:The dimensions of this data are (1000, 33694).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1668.71it/s]
# INFO:root:The dimensions of this data are (1000, 18670).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# covid19-cytokine-storm
# 100%|██████████| 1000/1000 [00:00<00:00, 1696.42it/s]
# INFO:root:The dimensions of this data are (1000, 18670).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1696.40it/s]
# INFO:root:The dimensions of this data are (1000, 26361).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# covid19-periph-immuno
# 100%|██████████| 1000/1000 [00:00<00:00, 1822.05it/s]
# INFO:root:The dimensions of this data are (1000, 26361).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1828.57it/s]
# INFO:root:The dimensions of this data are (1000, 26349).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# fetal-liver
# 100%|██████████| 1000/1000 [00:00<00:00, 1697.39it/s]
# INFO:root:The dimensions of this data are (1000, 26349).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1700.15it/s]
# INFO:root:The dimensions of this data are (1000, 23832).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# fetal-lung
# 100%|██████████| 1000/1000 [00:00<00:00, 1719.02it/s]
# INFO:root:The dimensions of this data are (1000, 23832).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1722.15it/s]
# INFO:root:The dimensions of this data are (1000, 19798).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# hpsc-embryo-model
# 100%|██████████| 1000/1000 [00:00<00:00, 1603.30it/s]
# INFO:root:The dimensions of this data are (1000, 19798).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1608.49it/s]
# INFO:root:The dimensions of this data are (1000, 1772).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# human-cellular-landscape
# 100%|██████████| 1000/1000 [00:00<00:00, 1859.20it/s]
# INFO:root:The dimensions of this data are (1000, 1772).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1859.97it/s]
# INFO:root:The dimensions of this data are (1000, 33538).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# human-cornea
# 100%|██████████| 1000/1000 [00:00<00:00, 1668.41it/s]
# INFO:root:The dimensions of this data are (1000, 33538).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1666.90it/s]
# INFO:root:The dimensions of this data are (1000, 19791).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# human-epidermis
# 100%|██████████| 1000/1000 [00:00<00:00, 1734.32it/s]
# INFO:root:The dimensions of this data are (1000, 19791).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1714.66it/s]
# INFO:root:The dimensions of this data are (1000, 21).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# human-gallbladder
#   0%|          | 0/1000 [00:00<?, ?it/s]WARNING:root:Warning:The cell 28 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 38 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 163 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 167 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 179 fails to denormlize, and be deleted
#  18%|█▊        | 181/1000 [00:00<00:00, 1799.09it/s]WARNING:root:Warning:The cell 203 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 232 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 288 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 310 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 328 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 333 fails to denormlize, and be deleted
#  36%|███▌      | 361/1000 [00:00<00:00, 1792.29it/s]WARNING:root:Warning:The cell 365 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 441 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 445 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 467 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 468 fails to denormlize, and be deleted
#  54%|█████▍    | 542/1000 [00:00<00:00, 1797.93it/s]WARNING:root:Warning:The cell 555 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 607 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 672 fails to denormlize, and be deleted
#  73%|███████▎  | 726/1000 [00:00<00:00, 1811.54it/s]WARNING:root:Warning:The cell 727 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 767 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 886 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 900 fails to denormlize, and be deleted
#  91%|█████████ | 909/1000 [00:00<00:00, 1817.46it/s]WARNING:root:Warning:The cell 911 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 940 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 946 fails to denormlize, and be deleted
# 100%|██████████| 1000/1000 [00:00<00:00, 1807.14it/s]
# INFO:root:The dimensions of this data are (1000, 21).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
#   0%|          | 0/1000 [00:00<?, ?it/s]WARNING:root:Warning:The cell 28 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 38 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 163 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 167 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 179 fails to denormlize, and be deleted
#  18%|█▊        | 180/1000 [00:00<00:00, 1782.87it/s]WARNING:root:Warning:The cell 203 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 232 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 288 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 310 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 328 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 333 fails to denormlize, and be deleted
#  36%|███▌      | 359/1000 [00:00<00:00, 1779.24it/s]WARNING:root:Warning:The cell 365 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 441 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 445 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 467 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 468 fails to denormlize, and be deleted
#  54%|█████▍    | 538/1000 [00:00<00:00, 1783.37it/s]WARNING:root:Warning:The cell 555 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 607 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 672 fails to denormlize, and be deleted
#  72%|███████▏  | 720/1000 [00:00<00:00, 1795.06it/s]WARNING:root:Warning:The cell 727 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 767 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 886 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 900 fails to denormlize, and be deleted
#  90%|█████████ | 901/1000 [00:00<00:00, 1795.77it/s]WARNING:root:Warning:The cell 911 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 940 fails to denormlize, and be deleted
# WARNING:root:Warning:The cell 946 fails to denormlize, and be deleted
# 100%|██████████| 1000/1000 [00:00<00:00, 1789.30it/s]
# INFO:root:The dimensions of this data are (1000, 17180).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# human-hippo-axis
# 100%|██████████| 1000/1000 [00:00<00:00, 1781.97it/s]
# INFO:root:The dimensions of this data are (1000, 17180).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1807.89it/s]
# INFO:root:The dimensions of this data are (1000, 22340).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# human-ileum
# 100%|██████████| 1000/1000 [00:00<00:00, 1821.29it/s]
# INFO:root:The dimensions of this data are (1000, 22340).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1813.51it/s]
# INFO:root:The dimensions of this data are (1000, 16077).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# human-pancreas
# 100%|██████████| 1000/1000 [00:00<00:00, 1749.16it/s]
# INFO:root:The dimensions of this data are (1000, 16077).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1729.49it/s]
# INFO:root:The dimensions of this data are (1000, 22484).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# living-donor-kidney
# 100%|██████████| 1000/1000 [00:00<00:00, 1763.80it/s]
# INFO:root:The dimensions of this data are (1000, 22484).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1763.75it/s]
# INFO:root:The dimensions of this data are (1000, 17863).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# ln-mono-dc
# 100%|██████████| 1000/1000 [00:00<00:00, 1691.90it/s]
# INFO:root:The dimensions of this data are (1000, 17863).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1691.35it/s]
# INFO:root:The dimensions of this data are (1000, 15171).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# lung-interstitial-macrophage
# 100%|██████████| 1000/1000 [00:00<00:00, 1719.04it/s]
# INFO:root:The dimensions of this data are (1000, 15171).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1705.36it/s]
# INFO:root:The dimensions of this data are (1000, 20952).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# lung-smoking-effect
# 100%|██████████| 1000/1000 [00:00<00:00, 1567.09it/s]
# INFO:root:The dimensions of this data are (1000, 20952).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1558.39it/s]
# INFO:root:The dimensions of this data are (1000, 3005).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# mouse-cell-atlas
# 100%|██████████| 1000/1000 [00:00<00:00, 1855.32it/s]
# INFO:root:The dimensions of this data are (1000, 3005).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1836.15it/s]
# INFO:root:The dimensions of this data are (1000, 14498).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# mouse-dev-neocortex
# 100%|██████████| 1000/1000 [00:00<00:00, 1753.14it/s]
# INFO:root:The dimensions of this data are (1000, 14498).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1762.48it/s]
# INFO:root:The dimensions of this data are (1000, 14389).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# mouse-esophagus
# 100%|██████████| 1000/1000 [00:00<00:00, 1803.31it/s]
# INFO:root:The dimensions of this data are (1000, 14389).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1805.87it/s]
# INFO:root:The dimensions of this data are (1000, 17275).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# mouse-osteoblasts
# 100%|██████████| 1000/1000 [00:00<00:00, 1692.70it/s]
# INFO:root:The dimensions of this data are (1000, 17275).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1714.87it/s]
# INFO:root:The dimensions of this data are (1000, 22875).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# prostate-prostatic-urethra
# 100%|██████████| 1000/1000 [00:00<00:00, 1769.41it/s]
# INFO:root:The dimensions of this data are (1000, 22875).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1789.98it/s]
# INFO:root:The dimensions of this data are (1000, 21040).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# retinal-pigment-epi
# 100%|██████████| 1000/1000 [00:00<00:00, 1738.32it/s]
# INFO:root:The dimensions of this data are (1000, 21040).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1739.10it/s]
# INFO:root:The dimensions of this data are (1000, 21823).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# sea-urchin-dev
# 100%|██████████| 1000/1000 [00:00<00:00, 1636.29it/s]
# INFO:root:The dimensions of this data are (1000, 21823).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1655.69it/s]

# %%
rounding_ers[0].data
# Out:
# array([ 0.0000000e+00, -4.7683716e-07,  0.0000000e+00, ...,
#         0.0000000e+00,  0.0000000e+00,  3.8146973e-06], dtype=float32)

# %%
figsize(4,4)
plt.plot(ads_dn[0].data,rounding_ers[0].data,'o')
plt.grid(visible=False)
plt.xlabel('Values after denormlization')
plt.ylabel('Rounding errors')
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.savefig('figures/UCB/rounding_errors.pdf',dpi=300, bbox_inches='tight',transparent=True)

# %%
rounding_ers1=[]
for i,tmp2 in zip(h5_names,rounding_ers):
    tmp2=pd.DataFrame(tmp2.data)
    tmp2.columns=['error']
    tmp2['name']=i
    rounding_ers1.append(tmp2)

# %%
rounding_ers1=pd.concat(rounding_ers1)

# %%
fig,ax=plt.subplots()
sns.stripplot(data=rounding_ers1[rounding_ers1.name!='human-fovea-periphery'],y='name',x='error',ax=ax)
sns.despine()
plt.grid(visible=False)
plt.xlabel('Rounding errors')
plt.ylabel('Datasets')
plt.savefig('figures/UCB/rounding_errors3.pdf',dpi=300, bbox_inches='tight',transparent=True)

# %%
fig, ax = plt.subplots()
sns.stripplot(data=rounding_ers1[rounding_ers1.name != 'human-fovea-periphery'], y='name', x='error', ax=ax)
sns.despine(left=True)  # Remove left spine
plt.grid(visible=False)
ax.yaxis.set_visible(False)  # Hide y-axis
ax.set_yticklabels([])  # Remove y-tick labels
ax.spines['left'].set_visible(False)
plt.ylabel(' ')
xticks = [-0.005, 0, 0.005]
xtick_labels = ['-5', '0', '5']
plt.xticks(xticks, xtick_labels)
plt.xlabel(r'Rounding errors (x$10^{-3}$)')
plt.show()

# %% [markdown]
# ## reconstruction errros

# %%
h5_names1=['adult-testis', 'aging-brain', 'brain-dronc-seq', 'colorectal-cancer', 'fetal-liver', 'fetal-lung', 'hpsc-embryo-model',  'human-cornea', 'human-epidermis',  'human-hippo-axis', 'human-ileum', 'human-pancreas',  'mouse-dev-neocortex', 'mouse-esophagus', 'prostate-prostatic-urethra', 'retinal-pigment-epi', 'sea-urchin-dev']

# %%
recon_ers=[]
for i in h5_names1:
    ad=ads[i]
    ad.X.sort_indices()
    
    ad3=scdenorm(ad,verbose=1,cutoff=0.5)
    sc.pp.normalize_total(ad3, target_sum=10000)
    sc.pp.log1p(ad3)
    ad3.X.sort_indices()
    tmp2=ad.X.copy()
    tmp2.data=tmp2.data-ad3.X.data
    recon_ers.append(tmp2.copy())
# Out:
# INFO:root:The dimensions of this data are (1000, 27826).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1698.31it/s]
# INFO:root:The dimensions of this data are (1000, 19746).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1764.65it/s]
# INFO:root:The dimensions of this data are (1000, 25587).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1819.85it/s]
# INFO:root:The dimensions of this data are (1000, 33694).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1655.05it/s]
# INFO:root:The dimensions of this data are (1000, 26349).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1683.75it/s]
# INFO:root:The dimensions of this data are (1000, 23832).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1715.35it/s]
# INFO:root:The dimensions of this data are (1000, 19798).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1600.85it/s]
# INFO:root:The dimensions of this data are (1000, 33538).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1681.31it/s]
# INFO:root:The dimensions of this data are (1000, 19791).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1696.90it/s]
# INFO:root:The dimensions of this data are (1000, 17180).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1786.43it/s]
# INFO:root:The dimensions of this data are (1000, 22340).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1798.82it/s]
# INFO:root:The dimensions of this data are (1000, 16077).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1741.13it/s]
# INFO:root:The dimensions of this data are (1000, 14498).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1758.78it/s]
# INFO:root:The dimensions of this data are (1000, 14389).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1806.83it/s]
# INFO:root:The dimensions of this data are (1000, 22875).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1762.16it/s]
# INFO:root:The dimensions of this data are (1000, 21040).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1743.42it/s]
# INFO:root:The dimensions of this data are (1000, 21823).
# INFO:root:select base
# INFO:root:denormlizing ...the base is 2.718281828459045
# 100%|██████████| 1000/1000 [00:00<00:00, 1662.34it/s]

# %%
recon_ers1=[]
for i,tmp2 in zip(h5_names1,recon_ers):
    tmp2=pd.DataFrame(tmp2.data)
    tmp2.columns=['error']
    tmp2['name']=i
    recon_ers1.append(tmp2)

# %%
recon_ers1=pd.concat(recon_ers1)

# %%
recon_ers1
# Out:
#                 error            name
# 0       -5.960464e-08    adult-testis
# 1        0.000000e+00    adult-testis
# 2       -5.960464e-08    adult-testis
# 3       -5.960464e-08    adult-testis
# 4       -5.960464e-08    adult-testis
# ...               ...             ...
# 3841527 -1.490116e-08  sea-urchin-dev
# 3841528 -1.490116e-08  sea-urchin-dev
# 3841529 -1.490116e-08  sea-urchin-dev
# 3841530 -1.490116e-08  sea-urchin-dev
# 3841531 -1.490116e-08  sea-urchin-dev
#
# [36717099 rows x 2 columns]

# %%
recon_ers2=pd.concat([recon_ers1,pd.DataFrame({'error':[None]*len(h5_names),'name':h5_names})])

# %%
recon_ers2=recon_ers2.sort_values('name')

# %%
recon_ers2['error']=recon_ers2['error']*1e6

# %%
recon_ers2
# Out:
#             error            name
# 0       -0.059605    adult-testis
# 1718027  0.000000    adult-testis
# 1718028  0.238419    adult-testis
# 1718029  0.000000    adult-testis
# 1718030  0.000000    adult-testis
# ...           ...             ...
# 1280523  0.000000  sea-urchin-dev
# 1280524  0.000000  sea-urchin-dev
# 1280525  0.000000  sea-urchin-dev
# 1280513  0.000000  sea-urchin-dev
# 26            NaN  sea-urchin-dev
#
# [36717126 rows x 2 columns]

# %%
fig,ax=plt.subplots()
sns.boxplot(data=recon_ers2,y='name',x='error',ax=ax)
sns.despine()
plt.grid(visible=False)
plt.xlabel(r'Recovery errors (x$10^{-6}$)')
ax.yaxis.set_visible(False)  # Hide y-axis
ax.set_yticklabels([])  # Remove y-tick labels
ax.spines['left'].set_visible(False)
plt.ylabel(' ')
plt.savefig('figures/UCB/recon_errors2.pdf',dpi=300, bbox_inches='tight',transparent=True)

# %% [markdown]
# # plot rounding errors

# %%
len(rounding_ers)
# Out:
# 27

# %%
# Create a 5x4 subplot grid
fig, axs = plt.subplots(7, 4, figsize=(16, 28))

# Loop through each subplot and plot the data
for i in range(7):
    for j in range(4):
        try:
            ax = axs[i, j]
            ax.plot(ads_dn[i*4+j].data, rounding_ers[i*4+j].data, 'o')
            ax.grid(visible=False)
            ax.set_xlabel('Values after denormalization')
            ax.set_ylabel('Rounding errors')
            ax.set_title(h5_names[i*4+j])
            ax.spines['top'].set_visible(False)
            ax.spines['right'].set_visible(False)
        except:
            pass

# Adjust the spacing between subplots
plt.tight_layout()

# Display the figure
plt.show()

# %%
# Create a 5x4 subplot grid
fig, axs = plt.subplots(7, 4, figsize=(16, 28))

# Loop through each subplot and plot the data
for i in range(7):
    for j in range(4):
        try:
            ax = axs[i, j]
            smtx=ads_dn[i*4+j]
            cmean = np.array(smtx.mean(0))
            cvar = np.array(smtx.power(2).mean(0) - cmean ** 2)
            plot_mv(cmean,cvar,ax,title=h5_names[i*4+j],c='black',fit=False)
        except:
            pass

# Adjust the spacing between subplots
plt.tight_layout()

# Display the figure
plt.show()

# %%
smtx=ads_dn[0]

cmean = np.array(smtx.mean(0))
cvar = np.array(smtx.power(2).mean(0) - cmean ** 2)
#A
plot_mv(cmean,cvar,c='black',fit=False)

# %%
169/2048
# Out:
# 0.08251953125

# %%
48/300

# %%
108/1024
# Out:
# 0.10546875

# %%
188/2048
# Out:
# 0.091796875

# %%
15/300
# Out:
# 0.05
